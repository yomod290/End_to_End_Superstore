# %% [markdown]
# ## **Creación externals Locations**

# %%
# %sql
create external location if not exists bronze_ext_loc
url 'abfss://superstoredata@adsldevsuperstore.dfs.core.windows.net/bronze'
with(storage credential superstore_cred);

create external location if not exists silver_ext_loc
url 'abfss://superstoredata@adsldevsuperstore.dfs.core.windows.net/silver'
with(storage credential superstore_cred);

create external location if not exists gold_ext_loc
url 'abfss://superstoredata@adsldevsuperstore.dfs.core.windows.net/gold'
with(storage credential superstore_cred);

# %% [markdown]
# ## **Creación de Catalogo**

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS asbdevsuperstore;

# %% [markdown]
# ## **Creación de Schemas**

# %%
# %sql
create schema if not exists asbdevsuperstore.bronze_schema;
create schema if not exists asbdevsuperstore.silver_schema;
create schema if not exists asbdevsuperstore.gold_schema;
